# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load dataset
df = pd.read_csv("imdb_top_1000.csv")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
df['content'] = df['Genre'] + " " + df["Overview"] + " " + df['Director'] + " " + df['Star1'] +  " " + df['Star2'] +  " " + df['Star2'] + " " + df['Star4']
 
df['content'] = df['content'].str.lower()

df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  \
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000
#
#                                              content
# 0  drama two imprisoned men bond over a number of...
# 1  crime, drama an organized crime dynasty's agin...
# 2  action, crime, drama when the menace known as ...
# 3  crime, drama the early life and career of vito...
# 4  crime, drama a jury holdout attempts to preven...

# %%
# TF-IDF for Overview text
tfidf = TfidfVectorizer(stop_words='english', max_features=300)
overview_tfidf = tfidf.fit_transform(df['content'])

# Combine numerical and text features
features = np.hstack([
    df[['IMDB_Rating']].values,
    overview_tfidf.toarray()
    
])


features
# Out:
# array([[9.3       , 0.        , 0.        , ..., 0.35435667, 0.        ,
#         0.        ],
#        [9.2       , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [9.        , 0.        , 0.21353192, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [7.6       , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [7.6       , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [7.6       , 0.26828371, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
# Scale data
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Dimensionality reduction
pca = PCA(n_components=50)
features_reduced = pca.fit_transform(features_scaled)

# %%
# DBSCAN clustering
dbscan = DBSCAN(eps=10, min_samples=10, metric='euclidean')
df['Cluster'] = dbscan.fit_predict(features_reduced)

df['Cluster'].value_counts()
# Out:
# Cluster
#  0    899
# -1     83
#  2     10
#  1      8
# Name: count, dtype: int64

# %%
def recommend_movies(title, df, num_recommendations=5):
    if title not in df['Series_Title'].values:
        return "Movie not found in dataset."

    cluster_label = df[df['Series_Title'] == title]['Cluster'].values[0]


    cluster_movies = df[df['Cluster'] == cluster_label]
    movie_vector = overview_tfidf[df[df['Series_Title'] == title].index[0]]
    similarities = cosine_similarity(movie_vector, overview_tfidf[cluster_movies.index]).flatten()
    
    similar_indices = similarities.argsort()[-(num_recommendations + 1):-1][::-1]
    
    # Return selected columns in a DataFrame
    recommendations = cluster_movies.iloc[similar_indices][['Series_Title', 'Overview', 'IMDB_Rating', 'Poster_Link']]

    return recommendations.reset_index(drop=True)

# Example usage
recommend_movies("The Shawshank Redemption", df)
# Out:
#        Series_Title                                           Overview  \
# 0      Mystic River  The lives of three men who were childhood frie...
# 1           Network  A television network cynically exploits a dera...
# 2  Fa yeung nin wah  Two neighbors, a woman and a man, form a stron...
# 3    Reservoir Dogs  When a simple jewelry heist goes horribly wron...
# 4       Funny Games  Two violent young men take a mother, father, a...
#
#    IMDB_Rating                                        Poster_Link
# 0          7.9  https://m.media-amazon.com/images/M/MV5BMTIzND...
# 1          8.1  https://m.media-amazon.com/images/M/MV5BZGNjYj...
# 2          8.1  https://m.media-amazon.com/images/M/MV5BYjZjOD...
# 3          8.3  https://m.media-amazon.com/images/M/MV5BZmExNm...
# 4          7.6  https://m.media-amazon.com/images/M/MV5BMTkyNT...

# %%
recommend_movies("Judgment at Nuremberg",df)
# Out:
#                    Series_Title  \
# 0             Full Metal Jacket
# 1                   Underground
# 2           Beasts of No Nation
# 3                Paths of Glory
# 4  Guess Who's Coming to Dinner
#
#                                             Overview  IMDB_Rating  \
# 0  A pragmatic U.S. Marine observes the dehumaniz...          8.3
# 1  A group of Serbian socialists prepares for the...          8.1
# 2  A drama based on the experiences of Agu, a chi...          7.7
# 3  After refusing to attack an enemy position, a ...          8.4
# 4  A couple's attitudes are challenged when their...          7.8
#
#                                          Poster_Link
# 0  https://m.media-amazon.com/images/M/MV5BNzkxOD...
# 1  https://m.media-amazon.com/images/M/MV5BNzI4YT...
# 2  https://m.media-amazon.com/images/M/MV5BMTYwMz...
# 3  https://m.media-amazon.com/images/M/MV5BNjViMm...
# 4  https://m.media-amazon.com/images/M/MV5BZTVmMT...

# %%
df.to_csv("clustered_df.csv",index=False)


import pickle
pickle.dump(overview_tfidf,open("overview_tfidf.pkl",'wb'))
